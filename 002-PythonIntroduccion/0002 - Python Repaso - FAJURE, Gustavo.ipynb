# %% [markdown]
# # TP 02 \- Introducción a Python

# %% [markdown]
# Fajure Gustavo Marcelo

# %% [markdown]
# ## Ejercicio 1 \- Variables y Operaciones

# %%
nombre = "Gustavo"
edad = 32
ciudad = "Bernal"
print ("Hola, mi nombre es", nombre, "tengo", edad, "años y vivo en", ciudad)
# Out:
# Hola, mi nombre es Gustavo tengo 32 años y vivo en Bernal

# %%
a = 6
b = 3
suma = a + b
resta = a - b
multiplicacion = a * b
division = a / b

print ("El resultado de la suma es", suma)
print ("El resultado de la resta es", resta)
print ("El resultado de la multiplicacion es", multiplicacion)
print ("El resultado de la division es", division)
# Out:
# El resultado de la suma es 9
# El resultado de la resta es 3
# El resultado de la multiplicacion es 18
# El resultado de la division es 2.0

# %% [markdown]
# ## Ejercicio 2 \- Condicionales

# %%
edad = int (input ("Ingresa tu edad"))
if edad >= 18:
    print ("Sos mayor de edad.")
else:
    print ("Lo siento, sos menor de edad")
# Out:
# Lo siento, sos menor de edad

# %% [markdown]
# ## Ejercicio 3 \- Listas y bucles

# %%
numeros = [3, 4, 6, 9, 17]
for n in numeros:
    print (n)
# Out:
# 3
# 4
# 6
# 9
# 17

# %%
suma_total = 0
for n in numeros:
    suma_total +=n
print ("La suma total es:", suma_total)
# Out:
# La suma total es: 39

# %%
promedio = suma_total / len (numeros)
print ("El promedio es:", promedio)
# Out:
# El promedio es: 7.8

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fd186be5-1c3f-4da8-a8e8-3790a0c42e0c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
